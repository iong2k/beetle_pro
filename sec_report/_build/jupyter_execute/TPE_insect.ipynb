# %% [markdown]
# # 大台北地區蟲店點位

# %%
import requests #處理跟網路有關的東西
import json     #資料格式
import folium   #互動式地圖插件

#上述插件皆為python專用

# %%
overpass_url = "http://overpass-api.de/api/interpreter" #引號內為文字(URL、list、純文字)/變數
overpass_query = """[out:json];node["note"="insect"](21.8,119.5,25.4,122.0);out;"""

#"""為overpass request的格式，內容為overpass語法:"""[out:資料格式]；[空間向量資料=標籤]；(空間範圍)；out；/變數

# %%
response = requests.get(overpass_url, params={'data': overpass_query}) #.get為requests的一項功能，用來擷取API服務的回應，參數=服務方定義
data = response.json() #以JSON檔讀取的回應

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.62.1 084b4234',
#  'osm3s': {'timestamp_osm_base': '2024-07-30T11:40:45Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 3811140839,
#    'lat': 25.0058396,
#    'lon': 121.5387799,
#    'tags': {'addr:city': '臺北市',
#     'addr:country': 'TW',
#     'addr:district': '文山區',
#     'addr:floor': '4',
#     'addr:full': '116臺北市文山區萬年里5鄰羅斯福路五段136之1號四樓',
#     'addr:hamlet': '萬年里',
#     'addr:housenumber': '136之1',
#     'addr:neighbourhood': '5',
#     'addr:postcode': '116',
#     'addr:street': '羅斯福路五段',
#     'disused:shop': 'erotic',
#     'name': '阿文蟲坊',
#     'note': 'insect',
#     'shop': 'pet'}},
#   {'type': 'node',
#    'id': 5495163221,
#    'lat': 25.0907021,
#    'lon': 121.5255365,
#    'tags': {'addr:city': '臺北市',
#     'addr:country': 'TW',
#     'addr:district': '士林區',
#     'addr:housenumber': '79',
#     'addr:postcode': '111',
#     'addr:street': '大東路',
#     'atm': 'yes',
#     'name': '蟲磨坊',
#     'note': 'insect',
#     'shop': 'pet',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'limited',
#     'wheelchair:description': '0'}},
#   {'type': 'node',
#    'id': 7964935469,
#    'lat': 25.0416169,
#    'lon': 121.5697339,
#    'tags': {'name': '蟲林野售', 'note': 'insect', 'shop': 'pet'}},
#   {'type': 'node',
#    'id': 10826550020,
#    'lat': 25.0627148,
#    'lon': 121.531905,
#    'tags': {'addr:TW:dataset': '155472',
#     'addr:city': '臺北市',
#     'addr:country': 'TW',
#     'addr:district': '中山區',
#     'addr:floor': '3',
#     'addr:full': '104臺北市中山區新福里5鄰民權東路二段77號',
#     'addr:hamlet': '新福里',
#     'addr:housenumber': '77號',
#     'addr:neighbourhood': '5',
#     'addr:postcode': '104',
#     'addr:street': '民權東路二段',
#     'name': '六足企業社',
#     'note': 'insect',
#     'shop': 'pet',
#     'source': '臺北市政府'}},
#   {'type': 'node',
#    'id': 10826550939,
#    'lat': 25.0631388,
#    'lon': 121.5322744,
#    'tags': {'addr:TW:dataset': '155472',
#     'addr:city': '臺北市',
#     'addr:country': 'TW',
#     'addr:district': '中山區',
#     'addr:full': '104臺北市中山區新福里4鄰松江路372巷13號',
#     'addr:hamlet': '新福里',
#     'addr:housenumber': '13號',
#     'addr:neighbourhood': '4',
#     'addr:postcode': '104',
#     'addr:street': '松江路372巷',
#     'name': '木生昆虫坊',
#     'note': 'insect',
#     'shop': 'pet',
#     'source': '臺北市政府'}},
#   {'type': 'node',
#    'id': 10826580076,
#    'lat': 25.030499,
#    'lon': 121.5257495,
#    'tags': {'addr:TW:dataset': '155472',
#     'addr:city': '臺北市',
#     'addr:country': 'TW',
#     'addr:district': '大安區',
#     'addr:full': '106臺北市大安區錦泰里5鄰金華街159號',
#     'addr:hamlet': '錦泰里',
#     'addr:housenumber': '159號',
#     'addr:neighbourhood': '5',
#     'addr:postcode': '106',
#     'addr:street': '金華街',
#     'name': '甲蟲秘境榕錦時光外賣店',
#     'note': 'insect',
#     'shop': 'pet',
#     'source': '臺北市政府'}},
#   {'type': 'node',
#    'id': 12079643050,
#    'lat': 25.0270472,
#    'lon': 121.5695069,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': '甲蟲秘境親子咖啡廳 象山店',
#     'note': 'insect'}},
#   {'type': 'node',
#    'id': 12079643051,
#    'lat': 25.0044539,
#    'lon': 121.5365663,
#    'tags': {'name': '蟲殿甲蟲專賣店', 'note': 'insect', 'shop': 'pet'}},
#   {'type': 'node',
#    'id': 12079680772,
#    'lat': 24.9980015,
#    'lon': 121.503833,
#    'tags': {'addr:city': '新北市',
#     'addr:district': '中和區',
#     'addr:floor': '1',
#     'addr:housenumber': '24',
#     'addr:postcode': '235',
#     'addr:street': '南山路127巷27弄',
#     'name': '星虫坊甲蟲生態工作室',
#     'note': 'insect',
#     'shop': 'pet'}},
#   {'type': 'node',
#    'id': 12079706458,
#    'lat': 25.0640552,
#    'lon': 121.5338087,
#    'tags': {'addr:city': '台北市',
#     'addr:district': '中山區',
#     'addr:floor': 'B1',
#     'addr:housenumber': '6',
#     'addr:postcode': '104',
#     'addr:street': '農安街166巷',
#     'name': '蟲殿行天宮館',
#     'note': 'insect',
#     'shop': 'pet'}},
#   {'type': 'node',
#    'id': 12079710137,
#    'lat': 24.9840147,
#    'lon': 121.4677425,
#    'tags': {'addr:city': '新北市',
#     'addr:district': '土城區',
#     'addr:floor': '1',
#     'addr:housenumber': '22',
#     'addr:street': '延吉街253巷',
#     'name': '虹森林工作室',
#     'note': 'insect',
#     'shop': 'pet'}},
#   {'type': 'node',
#    'id': 12079710139,
#    'lat': 25.0104694,
#    'lon': 121.4526514,
#    'tags': {'addr:city': '新北市',
#     'addr:district': '板橋區',
#     'addr:floor': '1',
#     'addr:housenumber': '74',
#     'addr:postcode': '220',
#     'addr:street': '南雅西路二段',
#     'name': '魔晶園',
#     'note': 'insect',
#     'shop': 'pet'}},
#   {'type': 'node',
#    'id': 12079725244,
#    'lat': 25.0340535,
#    'lon': 121.4433208,
#    'tags': {'addr:city': '新北市',
#     'addr:district': '新莊區',
#     'addr:floor': '1',
#     'addr:housenumber': '437',
#     'addr:postcode': '24255',
#     'addr:street': '中正路',
#     'name': '喜蟲天降',
#     'note': 'insect',
#     'shop': 'pet'}},
#   {'type': 'node',
#    'id': 12079725245,
#    'lat': 25.0623605,
#    'lon': 121.4880818,
#    'tags': {'addr:city': '新北市',
#     'addr:district': '三重區',
#     'addr:housenumber': '15',
#     'addr:postcode': '24141',
#     'addr:street': '重陽路二段19巷',
#     'name': '喜蟲天降三重店',
#     'note': 'insect',
#     'shop': 'pet'}}]}

# %%
m = folium.Map(location=[25.0462394, 121.5309870], zoom_start=12) #m為地圖，.Map用來生成地圖(定義中心坐標，再設定尺度zoom_start，數字和比例成正比)

for element in data['elements']: #for...in為迴圈、element為個別參數
    lat = element['lat']
    lon = element['lon']
    name = element.get('tags', {}).get('name')
    #上述為資料定義
    folium.Marker(
        location=[lat, lon],
        popup=name,
        icon=folium.Icon(icon='info-sign')
    ).add_to(m)
# https://python-visualization.github.io/folium/version-v0.14.0/modules.html?highlight=marker#folium.map.Marker 變數的定義
# 顯示地圖
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a14bff6f76c134e1ca0db79ce84d8f17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a14bff6f76c134e1ca0db79ce84d8f17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a14bff6f76c134e1ca0db79ce84d8f17 = L.map(
#                 &quot;map_a14bff6f76c134e1ca0db79ce84d8f17&quot;,
#                 {
#                     center: [25.0462394, 121.530987],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f54b6e1a60f159be1a310e504655c98e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f54b6e1a60f159be1a310e504655c98e.addTo(map_a14bff6f76c134e1ca0db79ce84d8f17);
#
#
#             var marker_ed89a29ec14cafe5101a0b85a4d3c8d2 = L.marker(
#                 [25.0058396, 121.5387799],
#                 {}
#             ).addTo(map_a14bff6f76c134e1ca0db79ce84d8f17);
#
#
#             var icon_c09f3555c3784c3d72d57a1b0e22e22d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ed89a29ec14cafe5101a0b85a4d3c8d2.setIcon(icon_c09f3555c3784c3d72d57a1b0e22e22d);
#
#
#         var popup_7b4c56c0c526b2a73dd7b8c838a14d60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b61d8b3ff8e85ceac677bdbabd62a60 = $(`&lt;div id=&quot;html_5b61d8b3ff8e85ceac677bdbabd62a60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;阿文蟲坊&lt;/div&gt;`)[0];
#                 popup_7b4c56c0c526b2a73dd7b8c838a14d60.setContent(html_5b61d8b3ff8e85ceac677bdbabd62a60);
#
#
#
#         marker_ed89a29ec14cafe5101a0b85a4d3c8d2.bindPopup(popup_7b4c56c0c526b2a73dd7b8c838a14d60)
#         ;
#
#
#
#
#             var marker_fbf457dde66cdeb320d1818fabc02474 = L.marker(
#                 [25.0907021, 121.5255365],
#                 {}
#             ).addTo(map_a14bff6f76c134e1ca0db79ce84d8f17);
#
#
#             var icon_2523f99593faf3ec4d05138929709321 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fbf457dde66cdeb320d1818fabc02474.setIcon(icon_2523f99593faf3ec4d05138929709321);
#
#
#         var popup_87c9991021e208565f019c567a439f37 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e9732120e8e3095f6ff01d861ea65f32 = $(`&lt;div id=&quot;html_e9732120e8e3095f6ff01d861ea65f32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;蟲磨坊&lt;/div&gt;`)[0];
#                 popup_87c9991021e208565f019c567a439f37.setContent(html_e9732120e8e3095f6ff01d861ea65f32);
#
#
#
#         marker_fbf457dde66cdeb320d1818fabc02474.bindPopup(popup_87c9991021e208565f019c567a439f37)
#         ;
#
#
#
#
#             var marker_c6279043ba02cb49598872a1cc65a80a = L.marker(
#                 [25.0416169, 121.5697339],
#                 {}
#             ).addTo(map_a14bff6f76c134e1ca0db79ce84d8f17);
#
#
#             var icon_4262dadd8d77790b1bd8022491efa768 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c6279043ba02cb49598872a1cc65a80a.setIcon(icon_4262dadd8d77790b1bd8022491efa768);
#
#
#         var popup_5fb4d42d06ad995013885fc72b0b2590 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3dce8633061a4022b00399dbc1072c1c = $(`&lt;div id=&quot;html_3dce8633061a4022b00399dbc1072c1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;蟲林野售&lt;/div&gt;`)[0];
#                 popup_5fb4d42d06ad995013885fc72b0b2590.setContent(html_3dce8633061a4022b00399dbc1072c1c);
#
#
#
#         marker_c6279043ba02cb49598872a1cc65a80a.bindPopup(popup_5fb4d42d06ad995013885fc72b0b2590)
#         ;
#
#
#
#
#             var marker_5cdbb87311e8ce37ea2d7a389974b58a = L.marker(
#                 [25.0627148, 121.531905],
#                 {}
#             ).addTo(map_a14bff6f76c134e1ca0db79ce84d8f17);
#
#
#             var icon_2f7e8a6dab6260b66a5007d618044dcd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&q
